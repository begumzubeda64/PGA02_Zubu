# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read the Data

# %%
raw_data = pd.read_excel(r"C:\zubeda\ML Assignement\Online Retail.xlsx")
raw_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Understanding and Pre-processing

# %%
raw_data.shape
# Out:
# (541909, 8)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
raw_data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
user_data = raw_data.dropna()
user_data.shape
# Out:
# (406829, 8)

# %%
user_data.Country.value_counts().reset_index()
# Out:
#                    index  Country
# 0         United Kingdom   361878
# 1                Germany     9495
# 2                 France     8491
# 3                   EIRE     7485
# 4                  Spain     2533
# 5            Netherlands     2371
# 6                Belgium     2069
# 7            Switzerland     1877
# 8               Portugal     1480
# 9              Australia     1259
# 10                Norway     1086
# 11                 Italy      803
# 12       Channel Islands      758
# 13               Finland      695
# 14                Cyprus      622
# 15                Sweden      462
# 16               Austria      401
# 17               Denmark      389
# 18                 Japan      358
# 19                Poland      341
# 20                   USA      291
# 21                Israel      250
# 22           Unspecified      244
# 23             Singapore      229
# 24               Iceland      182
# 25                Canada      151
# 26                Greece      146
# 27                 Malta      127
# 28  United Arab Emirates       68
# 29    European Community       61
# 30                   RSA       58
# 31               Lebanon       45
# 32             Lithuania       35
# 33                Brazil       32
# 34        Czech Republic       30
# 35               Bahrain       17
# 36          Saudi Arabia       10

# %%
user_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# **Creating Amount Feature**

# %%
user_data["Amount"] = user_data.Quantity * user_data.UnitPrice

#remove negative amount
user_data = user_data[user_data["Amount"] > 0]

user_data.shape
# Out:
# (397884, 9)

# %%
user_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34

# %%
user_data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# Amount         0
# dtype: int64

# %% [markdown]
# ### Create RFM model (Recency, Frequency, Monetary)

# %% [markdown]
# **Create customer Recency feature**

# %%
import datetime

#reference date as one day before the last transaction
ref_date = user_data.InvoiceDate.max()
ref_date = ref_date + datetime.timedelta(days=1)     #timedelta function returns to total number of seconds
ref_date
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
user_data['days_last_purchase'] = ref_date - user_data.InvoiceDate
user_data['days_last_purchase_num'] = user_data['days_last_purchase'].astype('timedelta64[D]')
user_data['days_last_purchase_num'].sample(5)
# Out:
# 380869     64.0
# 444932     33.0
# 178282    217.0
# 481909     21.0
# 149395    246.0
# Name: days_last_purchase_num, dtype: float64

# %%
#Customer transaction history
customer_hist_df = pd.DataFrame(user_data.groupby("CustomerID")["days_last_purchase_num"].min()).reset_index()
customer_hist_df.rename(columns={"days_last_purchase_num": "Recency"}, inplace=True)

customer_hist_df.head()
# Out:
#    CustomerID  Recency
# 0     12346.0    326.0
# 1     12347.0      2.0
# 2     12348.0     75.0
# 3     12349.0     19.0
# 4     12350.0    310.0

# %% [markdown]
# **Create Frequency and Monetary (Amount) feature**

# %%
customer_monetary = user_data[["CustomerID","Amount"]].groupby('CustomerID')["Amount"].sum().reset_index()
customer_hist_df = customer_hist_df.merge(customer_monetary, how='outer')

customer_freq = user_data[['CustomerID','Amount']].groupby('CustomerID')["Amount"].count().reset_index()
customer_freq.rename(columns={'Amount': 'Frequency'}, inplace=True)
customer_hist_df = customer_hist_df.merge(customer_freq, how='outer')

customer_hist_df = pd.DataFrame(customer_hist_df, columns=['CustomerID','Recency','Amount','Frequency'])
customer_hist_df.head()
# Out:
#    CustomerID  Recency    Amount  Frequency
# 0     12346.0    326.0  77183.60          1
# 1     12347.0      2.0   4310.00        182
# 2     12348.0     75.0   1797.24         31
# 3     12349.0     19.0   1757.55         73
# 4     12350.0    310.0    334.40         17

# %%
from sklearn import preprocessing

customer_hist_df['Recency_log'] = customer_hist_df["Recency"].apply(np.log)
customer_hist_df['Frequency_log'] = customer_hist_df["Frequency"].apply(np.log)
customer_hist_df['Amount_log'] = customer_hist_df["Amount"].apply(np.log)
features = ["Recency_log","Frequency_log","Amount_log"]

X = pd.DataFrame(customer_hist_df[features].values, columns=features)
X.head()
# Out:
#    Recency_log  Frequency_log  Amount_log
# 0     5.786897       0.000000   11.253942
# 1     0.693147       5.204007    8.368693
# 2     4.317488       3.433987    7.494007
# 3     2.944439       4.290459    7.471676
# 4     5.736572       2.833213    5.812338

# %% [markdown]
# ### KMeans Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

n_clusters = [2, 3, 4, 5, 6]

for k in n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=112)
    predict = kmeans.fit_predict(X)
    score = silhouette_score(X, predict, random_state=1)
    print("k = {}, Score = {}".format(k, score))
# Out:
# k = 2, Score = 0.3945178445812027
# k = 3, Score = 0.3023683059862129
# k = 4, Score = 0.30625195716981807
# k = 5, Score = 0.2807436175747306
# k = 6, Score = 0.2822786330537753

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
customer_hist_df1 = customer_hist_df.set_index("CustomerID")[["Recency_log", "Frequency_log", "Amount_log"]]
customer_hist_df1["Cluster"] = kmeans.labels_
customer_hist_df1.sample(10)
# Out:
#             Recency_log  Frequency_log  Amount_log  Cluster
# CustomerID
# 16403.0        5.743003       2.302585    5.178971        1
# 12836.0        4.077537       5.164786    7.868201        0
# 16723.0        4.510860       3.761200    6.378681        1
# 16235.0        3.713572       3.828641    6.765396        1
# 16875.0        4.204693       4.718499    7.647562        0
# 17120.0        5.451038       2.890372    5.728345        1
# 17640.0        4.465908       1.609438    6.432393        1
# 14601.0        2.397895       1.945910    5.365789        1
# 13171.0        3.091042       3.828641    6.149344        0
# 15193.0        4.110874       2.944439    6.213247        1

# %%
test = pd.DataFrame(customer_hist_df1.loc[13339.0, features]).T
print("Actual:")
print(customer_hist_df1.loc[13339.0, "Cluster"])
predict = kmeans.predict(test)
print("Predicted:")
predict[0]
# Out:
# Actual:
# 1
# Predicted:
# 1

# %%
y = pd.DataFrame(user_data.groupby('CustomerID')["Quantity"].sum())
y
# Out:
#             Quantity
# CustomerID
# 12346.0        74215
# 12347.0         2458
# 12348.0         2341
# 12349.0          631
# 12350.0          197
# ...              ...
# 18280.0           45
# 18281.0           54
# 18282.0          103
# 18283.0         1397
# 18287.0         1586
#
# [4338 rows x 1 columns]

# %%
y["Quantity_log"] = np.log(y["Quantity"])
y
# Out:
#             Quantity  Quantity_log
# CustomerID
# 12346.0        74215     11.214722
# 12347.0         2458      7.807103
# 12348.0         2341      7.758333
# 12349.0          631      6.447306
# 12350.0          197      5.283204
# ...              ...           ...
# 18280.0           45      3.806662
# 18281.0           54      3.988984
# 18282.0          103      4.634729
# 18283.0         1397      7.242082
# 18287.0         1586      7.368970
#
# [4338 rows x 2 columns]

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y["Quantity_log"], random_state = 100)

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = lr_model.predict(X_test)
result_df = pd.DataFrame(columns=["Predicted_quantity", "Actual_quantity"])
result_df["Predicted_quantity"] = predicted
result_df["Actual_quantity"] = y_test.values
result_df.index = y_test.index
result_df
# Out:
#             Predicted_quantity  Actual_quantity
# CustomerID
# 16422.0               9.719878        10.425372
# 15730.0               6.420626         6.535241
# 14607.0               8.871106         9.372969
# 12789.0               3.822512         1.386294
# 15004.0               6.599926         6.445720
# ...                        ...              ...
# 16713.0               8.365572         8.360773
# 16892.0               5.931934         5.476464
# 13213.0               6.728746         7.215240
# 14306.0               6.877620         6.980076
# 14713.0               7.463782         7.387090
#
# [1085 rows x 2 columns]

# %%
from sklearn.metrics import r2_score, mean_squared_error
import math

rmse = math.sqrt(mean_squared_error(y_test, predicted))
r2 = r2_score(y_test, predicted)

print('\nRMSE:', rmse)
print('R2 Score:', r2)
# Out:
# RMSE: 0.5605270208477203
# R2 Score: 0.8392596998327324

# %%
desc_count = np.arange(1, len(pd.unique(user_data["Description"])) + 1)
desc = pd.unique(user_data["Description"])
desc_dict = dict(zip(desc, desc_count))
desc_dict
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 1,
#  'WHITE METAL LANTERN': 2,
#  'CREAM CUPID HEARTS COAT HANGER': 3,
#  'KNITTED UNION FLAG HOT WATER BOTTLE': 4,
#  'RED WOOLLY HOTTIE WHITE HEART.': 5,
#  'SET 7 BABUSHKA NESTING BOXES': 6,
#  'GLASS STAR FROSTED T-LIGHT HOLDER': 7,
#  'HAND WARMER UNION JACK': 8,
#  'HAND WARMER RED POLKA DOT': 9,
#  'ASSORTED COLOUR BIRD ORNAMENT': 10,
#  "POPPY'S PLAYHOUSE BEDROOM ": 11,
#  "POPPY'S PLAYHOUSE KITCHEN": 12,
#  'FELTCRAFT PRINCESS CHARLOTTE DOLL': 13,
#  'IVORY KNITTED MUG COSY ': 14,
#  'BOX OF 6 ASSORTED COLOUR TEASPOONS': 15,
#  'BOX OF VINTAGE JIGSAW BLOCKS ': 16,
#  'BOX OF VINTAGE ALPHABET BLOCKS': 17,
#  'HOME BUILDING BLOCK WORD': 18,
#  'LOVE BUILDING BLOCK WORD': 19,
#  'RECIPE BOX WITH METAL HEART': 20,
#  'DOORMAT NEW ENGLAND': 21,
#  'JAM MAKING SET WITH JARS': 22,
#  'RED COAT RACK PARIS FASHION': 23,
#  'YELLOW COAT RACK PARIS FASHION': 24,
#  'BLUE COAT RACK PARIS FASHION': 25,
#  'BATH BUILDING BLOCK WORD': 26,
#  'ALARM CLOCK BAKELIKE PINK': 27,
#  'ALARM CLOCK BAKELIKE RED ': 28,
#  'ALARM CLOCK BAKELIKE GREEN': 29,
#  'PANDA AND BUNNIES STICKER SHEET': 30,
#  'STARS GIFT TAPE ': 31,
#  'INFLATABLE POLITICAL GLOBE ': 32,
#  'VINTAGE HEADS AND TAILS CARD GAME ': 33,
#  'SET/2 RED RETROSPOT TEA TOWELS ': 34,
#  'ROUND SNACK BOXES SET OF4 WOODLAND ': 35,
#  'SPACEBOY LUNCH BOX ': 36,
#  'LUNCH BOX I LOVE LONDON': 37,
#  'CIRCUS PARADE LUNCH BOX ': 38,
#  'CHARLOTTE BAG DOLLY GIRL DESIGN': 39,
#  'RED TOADSTOOL LED NIGHT LIGHT': 40,
#  ' SET 2 TEA TOWELS I LOVE LONDON ': 41,
#  'VINTAGE SEASIDE JIGSAW PUZZLES': 42,
#  'MINI JIGSAW CIRCUS PARADE ': 43,
#  'MINI JIGSAW SPACEBOY': 44,
#  'MINI PAINT SET VINTAGE ': 45,
#  'POSTAGE': 46,
#  "PAPER CHAIN KIT 50'S CHRISTMAS ": 47,
#  'EDWARDIAN PARASOL RED': 48,
#  'RETRO COFFEE MUGS ASSORTED': 49,
#  'SAVE THE PLANET MUG': 50,
#  'VINTAGE BILLBOARD DRINK ME MUG': 51,
#  'VINTAGE BILLBOARD LOVE/HATE MUG': 52,
#  'WOOD 2 DRAWER CABINET WHITE FINISH': 53,
#  'WOOD S/3 CABINET ANT WHITE FINISH': 54,
#  'WOODEN PICTURE FRAME WHITE FINISH': 55,
#  'WOODEN FRAME ANTIQUE WHITE ': 56,
#  'VICTORIAN SEWING BOX LARGE': 57,
#  'HOT WATER BOTTLE TEA AND SYMPATHY': 58,
#  'RED HANGING HEART T-LIGHT HOLDER': 59,
#  'JUMBO BAG PINK POLKADOT': 60,
#  'JUMBO  BAG BAROQUE BLACK WHITE': 61,
#  'JUMBO BAG CHARLIE AND LOLA TOYS': 62,
#  'STRAWBERRY CHARLOTTE BAG': 63,
#  'RED 3 PIECE RETROSPOT CUTLERY SET': 64,
#  'BLUE 3 PIECE POLKADOT CUTLERY SET': 65,
#  'SET/6 RED SPOTTY PAPER PLATES': 66,
#  'LUNCH BAG RED RETROSPOT': 67,
#  'STRAWBERRY LUNCH BOX WITH CUTLERY': 68,
#  'LUNCH BOX WITH CUTLERY RETROSPOT ': 69,
#  'PACK OF 72 RETROSPOT CAKE CASES': 70,
#  'PACK OF 60 DINOSAUR CAKE CASES': 71,
#  'PACK OF 60 PINK PAISLEY CAKE CASES': 72,
#  '60 TEATIME FAIRY CAKE CASES': 73,
#  'TOMATO CHARLIE+LOLA COASTER SET': 74,
#  'CHARLIE & LOLA WASTEPAPER BIN FLORA': 75,
#  'RED CHARLIE+LOLA PERSONAL DOORSIGN': 76,
#  'JUMBO STORAGE BAG SUKI': 77,
#  'JUMBO BAG PINK VINTAGE PAISLEY': 78,
#  'JAM MAKING SET PRINTED': 79,
#  'RETROSPOT TEA SET CERAMIC 11 PC ': 80,
#  'GIRLY PINK TOOL SET': 81,
#  'JUMBO SHOPPER VINTAGE RED PAISLEY': 82,
#  'AIRLINE LOUNGE,METAL SIGN': 83,
#  'WHITE SPOT RED CERAMIC DRAWER KNOB': 84,
#  'RED DRAWER KNOB ACRYLIC EDWARDIAN': 85,
#  'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN': 86,
#  'PHOTO CLIP LINE': 87,
#  'FELT EGG COSY CHICKEN': 88,
#  'PIGGY BANK RETROSPOT ': 89,
#  'SKULL SHOULDER BAG': 90,
#  "YOU'RE CONFUSING ME METAL SIGN ": 91,
#  'COOK WITH WINE METAL SIGN ': 92,
#  'GIN + TONIC DIET METAL SIGN': 93,
#  'YELLOW BREAKFAST CUP AND SAUCER': 94,
#  'PINK BREAKFAST CUP AND SAUCER ': 95,
#  'PAPER CHAIN KIT RETROSPOT': 96,
#  'SMALL HEART FLOWERS HOOK ': 97,
#  'TEA TIME DES TEA COSY': 98,
#  'FELT EGG COSY WHITE RABBIT ': 99,
#  'ZINC WILLIE WINKIE  CANDLE STICK': 100,
#  'CERAMIC CHERRY CAKE MONEY BANK': 101,
#  'RETROSPOT LARGE MILK JUG': 102,
#  'SET OF 6 FUNKY BEAKERS': 103,
#  'EDWARDIAN PARASOL BLACK': 104,
#  'EDWARDIAN PARASOL NATURAL': 105,
#  'CERAMIC STRAWBERRY CAKE MONEY BANK': 106,
#  'BLUE OWL SOFT TOY': 107,
#  'BALLOON ART MAKE YOUR OWN FLOWERS': 108,
#  'GLASS CLOCHE SMALL': 109,
#  'GUMBALL MONOCHROME COAT RACK': 110,
#  'DOORMAT FANCY FONT HOME SWEET HOME': 111,
#  'VINTAGE SNAKES & LADDERS': 112,
#  'CHOCOLATE CALCULATOR': 113,
#  'RECYCLING BAG RETROSPOT ': 114,
#  'TOY TIDY PINK POLKADOT': 115,
#  'ANTIQUE GLASS DRESSING TABLE POT': 116,
#  'IVORY GIANT GARDEN THERMOMETER': 117,
#  '3 TIER CAKE TIN GREEN AND CREAM': 118,
#  '3 TIER CAKE TIN RED AND CREAM': 119,
#  'SET 3 WICKER OVAL BASKETS W LIDS': 120,
#  'WOOD BLACK BOARD ANT WHITE FINISH': 121,
#  'COLOUR GLASS T-LIGHT HOLDER HANGING': 122,
#  'HANGING METAL HEART LANTERN': 123,
#  'HANGING MEDINA LANTERN SMALL': 124,
#  'NATURAL SLATE HEART CHALKBOARD ': 125,
#  'HEART OF WICKER SMALL': 126,
#  'HEART OF WICKER LARGE': 127,
#  'WHITE LOVEBIRD LANTERN': 128,
#  'CLASSIC METAL BIRDCAGE PLANT HOLDER': 129,
#  'CREAM HEART CARD HOLDER': 130,
#  'ENAMEL FLOWER JUG CREAM': 131,
#  'ENAMEL FIRE BUCKET CREAM': 132,
#  'ENAMEL BREAD BIN CREAM': 133,
#  'JUMBO BAG DOLLY GIRL DESIGN': 134,
#  'TRADITIONAL CHRISTMAS RIBBONS': 135,
#  'ORGANISER WOOD ANTIQUE WHITE ': 136,
#  'LUNCH BAG DOLLY GIRL DESIGN': 137,
#  'WHITE WIRE EGG HOLDER': 138,
#  'JUMBO BAG RED RETROSPOT': 139,
#  'CHILLI LIGHTS': 140,
#  'LIGHT GARLAND BUTTERFILES PINK': 141,
#  'WOODEN OWLS LIGHT GARLAND ': 142,
#  'FAIRY TALE COTTAGE NIGHTLIGHT': 143,
#  'HOME SMALL WOOD LETTERS': 144,
#  'GINGHAM HEART  DOORSTOP RED': 145,
#  'FIVE HEART HANGING DECORATION': 146,
#  'ASSORTED BOTTLE TOP  MAGNETS ': 147,
#  'FRIDGE MAGNETS US DINER ASSORTED': 148,
#  'HOMEMADE JAM SCENTED CANDLES': 149,
#  'FRIDGE MAGNETS LES ENFANTS ASSORTED': 150,
#  'ROSE CARAVAN DOORSTOP': 151,
#  '5 HOOK HANGER MAGIC TOADSTOOL': 152,
#  'CHRISTMAS LIGHTS 10 REINDEER': 153,
#  'VINTAGE UNION JACK CUSHION COVER': 154,
#  'SET OF 3 COLOURED  FLYING DUCKS': 155,
#  'SET OF 3 GOLD FLYING DUCKS': 156,
#  'RED RETROSPOT UMBRELLA': 157,
#  'BLACK/BLUE POLKADOT UMBRELLA': 158,
#  'RED DINER WALL CLOCK': 159,
#  'BLUE DINER WALL CLOCK': 160,
#  'IVORY DINER WALL CLOCK': 161,
#  'LARGE HEART MEASURING SPOONS': 162,
#  'SMALL HEART MEASURING SPOONS': 163,
#  'JAM JAR WITH PINK LID': 164,
#  'JAM JAR WITH GREEN LID': 165,
#  'ROSE COTTAGE KEEPSAKE BOX ': 166,
#  'HANGING HEART ZINC T-LIGHT HOLDER': 167,
#  'PAPER CHAIN KIT VINTAGE CHRISTMAS': 168,
#  'DISCO BALL CHRISTMAS DECORATION': 169,
#  'SMALL POPCORN HOLDER': 170,
#  'LARGE POPCORN HOLDER ': 171,
#  'SET/20 RED RETROSPOT PAPER NAPKINS ': 172,
#  'SET/6 RED SPOTTY PAPER CUPS': 173,
#  'POLKADOT RAIN HAT ': 174,
#  'DELUXE SEWING KIT ': 175,
#  'RETROSPOT HEART HOT WATER BOTTLE': 176,
#  'ENGLISH ROSE HOT WATER BOTTLE': 177,
#  'PHOTO CUBE': 178,
#  '3 STRIPEY MICE FELTCRAFT': 179,
#  'SET OF 6 SOLDIER SKITTLES': 180,
#  'TRADITIONAL WOODEN SKIPPING ROPE': 181,
#  'WOODEN BOX OF DOMINOES': 182,
#  'RUSTIC  SEVENTEEN DRAWER SIDEBOARD': 183,
#  'PARTY CONES CARNIVAL ASSORTED': 184,
#  'PARTY CONES CANDY ASSORTED': 185,
#  'PICNIC BASKET WICKER SMALL': 186,
#  'STAR DECORATION PAINTED ZINC ': 187,
#  'RETROSPOT LAMP': 188,
#  'FANCY FONT BIRTHDAY CARD, ': 189,
#  'HAND WARMER SCOTTY DOG DESIGN': 190,
#  'HAND WARMER OWL DESIGN': 191,
#  'HAND WARMER RED RETROSPOT': 192,
#  'DOG BOWL CHASING BALL DESIGN': 193,
#  'CLOTHES PEGS RETROSPOT PACK 24 ': 194,
#  'HAND OVER THE CHOCOLATE   SIGN ': 195,
#  'TRAVEL SEWING KIT': 196,
#  'BLACK HEART CARD HOLDER': 197,
#  'CHICK GREY HOT WATER BOTTLE': 198,
#  'SMALL GLASS HEART TRINKET POT': 199,
#  'ALARM CLOCK BAKELIKE IVORY': 200,
#  'ALARM CLOCK BAKELIKE ORANGE': 201,
#  'HAND WARMER BIRD DESIGN': 202,
#  'IVORY EMBROIDERED QUILT ': 203,
#  'SET OF 3 BLACK FLYING DUCKS': 204,
#  'PACK OF 12 RED RETROSPOT TISSUES ': 205,
#  'RED RETROSPOT MUG': 206,
#  'BABUSHKA LIGHTS STRING OF 10': 207,
#  'DOORMAT FAIRY CAKE': 208,
#  'STRAWBERRY CERAMIC TRINKET BOX': 209,
#  'PINK DOUGHNUT TRINKET POT ': 210,
#  'SILK PURSE BABUSHKA PINK': 211,
#  'HOT WATER BOTTLE I AM SO POORLY': 212,
#  'CHOCOLATE HOT WATER BOTTLE': 213,
#  'WHITE SKULL HOT WATER BOTTLE ': 214,
#  'SCOTTIE DOG HOT WATER BOTTLE': 215,
#  'BIRD HOUSE HOT WATER BOTTLE': 216,
#  'BOUDOIR SQUARE TISSUE BOX': 217,
#  'SKULLS SQUARE TISSUE BOX': 218,
#  'PHOTO FRAME CORNICE': 219,
#  'SILK PURSE BABUSHKA RED': 220,
#  'PICTURE DOMINOES': 221,
#  'S/6 SEW ON CROCHET FLOWERS': 222,
#  'SCANDINAVIAN REDS RIBBONS': 223,
#  'BALLOONS  WRITING SET ': 224,
#  'LAVENDER INCENSE IN TIN': 225,
#  'TV DINNER TRAY VINTAGE PAISLEY': 226,
#  'SET OF 4 ENGLISH ROSE PLACEMATS': 227,
#  'SET OF 4 ENGLISH ROSE COASTERS': 228,
#  'TRIPLE PHOTO FRAME CORNICE ': 229,
#  'FAMILY PHOTO FRAME CORNICE': 230,
#  'MIRRORED DISCO BALL ': 231,
#  'DISCO BALL ROTATOR BATTERY OPERATED': 232,
#  'SILVER LOOKING MIRROR': 233,
#  'LADIES & GENTLEMEN METAL SIGN': 234,
#  'METAL SIGN HER DINNER IS SERVED ': 235,
#  'DOORMAT TOPIARY': 236,
#  'BATHROOM METAL SIGN': 237,
#  'KITCHEN METAL SIGN': 238,
#  'TOILET METAL SIGN': 239,
#  'METAL SIGN TAKE IT OR LEAVE IT ': 240,
#  "I'M ON HOLIDAY METAL SIGN": 241,
#  'GROW YOUR OWN BASIL IN ENAMEL MUG': 242,
#  'SET/10 PINK POLKADOT PARTY CANDLES': 243,
#  'SET 20 NAPKINS FAIRY CAKES DESIGN ': 244,
#  'SET OF 6 T-LIGHTS SNOWMEN': 245,
#  'SET OF 6 T-LIGHTS SANTA': 246,
#  'SET OF 9 HEART SHAPED BALLOONS': 247,
#  'SANDWICH BATH SPONGE': 248,
#  'APPLE BATH SPONGE': 249,
#  'STRAWBERRY BATH SPONGE ': 250,
#  'BLACK PIRATE TREASURE CHEST': 251,
#  'STAR PORTABLE TABLE LIGHT ': 252,
#  'SNOWFLAKE PORTABLE TABLE LIGHT ': 253,
#  'PINK OVAL JEWELLED MIRROR': 254,
#  'RETROSPOT CIGAR BOX MATCHES ': 255,
#  'COSY HOUR GIANT TUBE MATCHES': 256,
#  'JAZZ HEARTS PURSE NOTEBOOK': 257,
#  'CANDLEHOLDER PINK HANGING HEART': 258,
#  'ASSORTED COLOUR MINI CASES': 259,
#  'LUNCH BAG SPACEBOY DESIGN ': 260,
#  'LUNCH BAG WOODLAND': 261,
#  'LUNCH BAG PINK POLKADOT': 262,
#  'GUMBALL COAT RACK': 263,
#  'BLUE NEW BAROQUE CANDLESTICK CANDLE': 264,
#  'PINK NEW BAROQUECANDLESTICK CANDLE': 265,
#  'FAIRY CAKE FLANNEL ASSORTED COLOUR': 266,
#  'BREAD BIN DINER STYLE PINK': 267,
#  'TEA TIME TABLE CLOTH': 268,
#  'HOT WATER BOTTLE BABUSHKA ': 269,
#  'HEART IVORY TRELLIS SMALL': 270,
#  'PINK DRAWER KNOB ACRYLIC EDWARDIAN': 271,
#  'GREEN DRAWER KNOB ACRYLIC EDWARDIAN': 272,
#  'BLUE DRAWER KNOB ACRYLIC EDWARDIAN': 273,
#  'SET 6 FOOTBALL CELEBRATION CANDLES': 274,
#  'SET OF 6 GIRLS CELEBRATION CANDLES': 275,
#  'ROMANTIC PINKS RIBBONS ': 276,
#  'BRIGHT BLUES RIBBONS ': 277,
#  'CHOCOLATE BOX RIBBONS ': 278,
#  'PARTY INVITES FOOTBALL': 279,
#  'PARTY INVITES JAZZ HEARTS': 280,
#  'PARTY INVITES SPACEMAN': 281,
#  'SET OF 3 BUTTERFLY COOKIE CUTTERS': 282,
#  'SET OF 3 HEART COOKIE CUTTERS': 283,
#  '3 PIECE SPACEBOY COOKIE CUTTER SET': 284,
#  'PACK OF 72 SKULL CAKE CASES': 285,
#  'PACK OF 60 SPACEBOY CAKE CASES': 286,
#  '72 SWEETHEART FAIRY CAKE CASES': 287,
#  'LUNCH BAG SUKI  DESIGN ': 288,
#  'LUNCH BAG CARS BLUE': 289,
#  'LUNCH BAG  BLACK SKULL.': 290,
#  'HEART IVORY TRELLIS LARGE': 291,
#  'SET/5 RED RETROSPOT LID GLASS BOWLS': 292,
#  'MAGIC DRAWING SLATE DINOSAUR': 293,
#  'MAGIC DRAWING SLATE BAKE A CAKE ': 294,
#  '12 PENCILS TALL TUBE SKULLS': 295,
#  'RED  HARMONICA IN BOX ': 296,
#  'BLUE HARMONICA IN BOX ': 297,
#  'SKULLS  WATER TRANSFER TATTOOS ': 298,
#  'PACK 3 BOXES BIRD PANNETONE ': 299,
#  'SET OF 20 KIDS COOKIE CUTTERS': 300,
#  '10 COLOUR SPACEBOY PEN': 301,
#  'VICTORIAN GLASS HANGING T-LIGHT': 302,
#  'SINGLE HEART ZINC T-LIGHT HOLDER': 303,
#  'HANGING METAL STAR LANTERN': 304,
#  'SILVER HANGING T-LIGHT HOLDER': 305,
#  'DOORMAT RED RETROSPOT': 306,
#  'DOORMAT HEARTS': 307,
#  'NATURAL SLATE RECTANGLE CHALKBOARD': 308,
#  'LOVEBIRD HANGING DECORATION WHITE ': 309,
#  'PENS ASSORTED FUNNY FACE': 310,
#  'CARD CIRCUS PARADE': 311,
#  'WRAP COWBOYS  ': 312,
#  'AIRLINE BAG VINTAGE TOKYO 78': 313,
#  'SET OF 72 RETROSPOT PAPER  DOILIES': 314,
#  'PLASTERS IN TIN SKULLS': 315,
#  'SLEEPING CAT ERASERS': 316,
#  'CARD BIRTHDAY COWBOY': 317,
#  'PACK 3 BOXES CHRISTMAS PANNETONE': 318,
#  'ROTATING SILVER ANGELS T-LIGHT HLDR': 319,
#  'RIBBON REEL MAKING SNOWMEN ': 320,
#  '4 TRADITIONAL SPINNING TOPS': 321,
#  'BAG 500g SWIRLY MARBLES': 322,
#  '5 STRAND GLASS NECKLACE CRYSTAL': 323,
#  'SQUARECUSHION COVER PINK UNION FLAG': 324,
#  'SPACEBOY CHILDRENS EGG CUP': 325,
#  "CHILDREN'S SPACEBOY MUG": 326,
#  'FELTCRAFT CUSHION OWL': 327,
#  'BLACK CANDELABRA T-LIGHT HOLDER': 328,
#  'TOY TIDY DOLLY GIRL DESIGN': 329,
#  'SET 12 LAVENDER  BOTANICAL T-LIGHTS': 330,
#  'UNION JACK FLAG LUGGAGE TAG': 331,
#  'RED HEART LUGGAGE TAG': 332,
#  'RED GLASS TASSLE BAG CHARM': 333,
#  'CLEAR ACRYLIC FACETED BANGLE': 334,
#  'DOORMAT UNION JACK GUNS AND ROSES': 335,
#  'VANILLA SCENT CANDLE JEWELLED BOX': 336,
#  'FULL ENGLISH BREAKFAST PLATE': 337,
#  'MAGIC DRAWING SLATE CIRCUS PARADE  ': 338,
#  'CHRISTMAS HANGING HEART WITH BELL': 339,
#  'CAKE STAND VICTORIAN FILIGREE MED': 340,
#  'PAISLEY PATTERN  STICKERS': 341,
#  'FLOWERS  STICKERS': 342,
#  'BLACK LOVE BIRD CANDLE': 343,
#  'PARTY TIME PENCIL ERASERS': 344,
#  "PINK B'FLY C/COVER W BOBBLES": 345,
#  'PINK UNION JACK  LUGGAGE TAG': 346,
#  '6 RIBBONS ELEGANT CHRISTMAS ': 347,
#  'AGED GLASS SILVER T-LIGHT HOLDER': 348,
#  'BOOM BOX SPEAKER GIRLS': 349,
#  '6 RIBBONS SHIMMERING PINKS ': 350,
#  'JUMBO BAG OWLS': 351,
#  'OWL DOORSTOP': 352,
#  'PAINTED METAL STAR WITH HOLLY BELLS': 353,
#  'PAINTED METAL HEART WITH HOLLY BELL': 354,
#  'ANGEL DECORATION STARS ON DRESS': 355,
#  'JUMBO BAG STRAWBERRY': 356,
#  'STRAWBERRY SHOPPER BAG': 357,
#  'ROUND SNACK BOXES SET OF 4 FRUITS ': 358,
#  'ROUND SNACK BOXES SET OF 4 SKULLS': 359,
#  'DOLLY GIRL LUNCH BOX': 360,
#  'GREEN POLKADOT PLATE ': 361,
#  'BLUE POLKADOT PLATE ': 362,
#  'RED RETROSPOT PLATE ': 363,
#  'PINK  POLKADOT PLATE ': 364,
#  'FELTCRAFT DOLL MOLLY': 365,
#  'FELTCRAFT CHRISTMAS FAIRY': 366,
#  'SET OF 3 NOTEBOOKS IN PARCEL': 367,
#  'RED RETROSPOT TAPE': 368,
#  'COSY SLIPPER SHOES SMALL  RED ': 369,
#  '6 RIBBONS RUSTIC CHARM': 370,
#  '12 DAISY PEGS IN WOOD BOX': 371,
#  '5 HOOK HANGER RED MAGIC TOADSTOOL': 372,
#  'CHRISTMAS CRAFT TREE TOP ANGEL': 373,
#  'CHRISTMAS CRAFT LITTLE FRIENDS': 374,
#  'COSY SLIPPER SHOES SMALL GREEN': 375,
#  'FELTCRAFT DOLL ROSIE': 376,
#  'FELTCRAFT DOLL EMILY': 377,
#  'FELTCRAFT PRINCESS OLIVIA DOLL': 378,
#  'REX CASH+CARRY JUMBO SHOPPER': 379,
#  'FELTCRAFT CUSHION RABBIT': 380,
#  'FELTCRAFT CUSHION BUTTERFLY': 381,
#  'TOTE BAG I LOVE LONDON': 382,
#  'FOLDING UMBRELLA PINKWHITE POLKADOT': 383,
#  'FOLDING UMBRELLA CREAM POLKADOT': 384,
#  'FOLDING UMBRELLA WHITE/RED POLKADOT': 385,
#  'SET 10 LIGHTS NIGHT OWL': 386,
#  'FOLDING UMBRELLA RED/WHITE POLKADOT': 387,
#  'S/4 VALENTINE DECOUPAGE HEART BOX': 388,
#  'SOLDIERS EGG CUP ': 389,
#  'RED RETROSPOT MINI CASES': 390,
#  '60 CAKE CASES VINTAGE CHRISTMAS': 391,
#  'RIBBON REEL CHRISTMAS SOCK BAUBLE': 392,
#  'RIBBON REEL SNOWY VILLAGE': 393,
#  'SET OF 20 VINTAGE CHRISTMAS NAPKINS': 394,
#  'TURQUOISE CHRISTMAS TREE ': 395,
#  'RED STAR CARD HOLDER': 396,
#  'WICKER WREATH SMALL': 397,
#  'ADVENT CALENDAR GINGHAM SACK': 398,
#  'FELTCRAFT BUTTERFLY HEARTS': 399,
#  'PARTY CONE CHRISTMAS DECORATION ': 400,
#  'WICKER STAR ': 401,
#  'VINTAGE SNAP CARDS': 402,
#  'FELTCRAFT 6 FLOWER FRIENDS': 403,
#  'BIRD DECORATION RED RETROSPOT': 404,
#  'CHRISTMAS GINGHAM TREE': 405,
#  'CHRISTMAS GINGHAM STAR': 406,
#  'CHRISTMAS GINGHAM HEART': 407,
#  'PACK OF 12 PINK POLKADOT TISSUES': 408,
#  'FELTCRAFT PRINCESS LOLA DOLL': 409,
#  'PACK OF 12 LONDON TISSUES ': 410,
#  'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN': 411,
#  "CHILDREN'S APRON DOLLY GIRL ": 412,
#  'CHILDRENS APRON SPACEBOY DESIGN': 413,
#  'CHRISTMAS LIGHTS 10 SANTAS ': 414,
#  'PACK OF 60 MUSHROOM CAKE CASES': 415,
#  '60 CAKE CASES DOLLY GIRL DESIGN': 416,
#  'HAND WARMER BABUSHKA DESIGN': 417,
#  'SET 12 RETRO WHITE CHALK STICKS': 418,
#  'FELTCRAFT HAIRBAND RED AND BLUE': 419,
#  'FELTCRAFT HAIRBAND PINK AND PURPLE': 420,
#  'FELTCRAFT HAIRBANDS PINK AND WHITE ': 421,
#  'TV DINNER TRAY DOLLY GIRL': 422,
#  'PLASTERS IN TIN VINTAGE PAISLEY ': 423,
#  'PLASTERS IN TIN SPACEBOY': 424,
#  'PLASTERS IN TIN WOODLAND ANIMALS': 425,
#  'MAGIC DRAWING SLATE SPACEBOY ': 426,
#  'MAGIC DRAWING SLATE GO TO THE FAIR ': 427,
#  'MAGIC DRAWING SLATE DOLLY GIRL ': 428,
#  'CHARLIE + LOLA RED HOT WATER BOTTLE': 429,
#  'URBAN BLACK RIBBONS ': 430,
#  'SET OF 6 T-LIGHTS TOADSTOOLS': 431,
#  'ROTATING LEAVES T-LIGHT HOLDER': 432,
#  'CUPCAKE LACE PAPER SET 6': 433,
#  'TRADITIONAL WOODEN CATCH CUP GAME ': 434,
#  'S/6 WOODEN SKITTLES IN COTTON BAG': 435,
#  'RED METAL BEACH SPADE ': 436,
#  'BOYS VINTAGE TIN SEASIDE BUCKET': 437,
#  'GIRLS VINTAGE TIN SEASIDE BUCKET': 438,
#  'GREY HEART HOT WATER BOTTLE': 439,
#  'KINGS CHOICE TEA CADDY ': 440,
#  'KINGS CHOICE BISCUIT TIN': 441,
#  'METAL SIGN EMPIRE TEA': 442,
#  'FAWN BLUE HOT WATER BOTTLE': 443,
#  'PACK OF 6 BIRDY GIFT TAGS': 444,
#  'CERAMIC STRAWBERRY MONEY BOX': 445,
#  'CERAMIC HEART FAIRY CAKE MONEY BANK': 446,
#  'CERAMIC PIRATE CHEST MONEY BANK': 447,
#  'DOORSTOP RETROSPOT HEART': 448,
#  'RETROSPOT BABUSHKA DOORSTOP': 449,
#  'SWEETHEART WIRE WALL TIDY': 450,
#  'RED RETROSPOT OVEN GLOVE ': 451,
#  'NAMASTE SWAGAT INCENSE': 452,
#  'CERAMIC STRAWBERRY DESIGN MUG': 453,
#  'CLASSICAL ROSE SMALL VASE': 454,
#  'HYACINTH BULB T-LIGHT CANDLES': 455,
#  'CHRISTMAS CRAFT WHITE FAIRY ': 456,
#  'COSY HOUR CIGAR BOX MATCHES ': 457,
#  'RED TEA TOWEL CLASSIC DESIGN': 458,
#  'HEART FILIGREE DOVE  SMALL': 459,
#  'RETROSPOT CHILDRENS APRON': 460,
#  'COLOURING PENCILS BROWN TUBE': 461,
#  '4 IVORY DINNER CANDLES SILVER FLOCK': 462,
#  'ZINC METAL HEART DECORATION': 463,
#  'GREEN FERN NOTEBOOK': 464,
#  'BLUE PAISLEY NOTEBOOK': 465,
#  'CHRYSANTHEMUM NOTEBOOK': 466,
#  'LARGE CHINESE STYLE SCISSOR': 467,
#  'SMALL CHINESE STYLE SCISSOR': 468,
#  'HANGING GLASS ETCHED TEALIGHT': 469,
#  'COOKING SET RETROSPOT': 470,
#  'KINGS CHOICE GIANT TUBE MATCHES': 471,
#  'PLACE SETTING WHITE STAR': 472,
#  'S/15 SILVER GLASS BAUBLES IN BAG': 473,
#  'FRENCH WC SIGN BLUE METAL': 474,
#  'FAIRY SOAP SOAP HOLDER': 475,
#  'GREEN GIANT GARDEN THERMOMETER': 476,
#  'BLUE GIANT GARDEN THERMOMETER': 477,
#  'VICTORIAN SEWING BOX SMALL ': 478,
#  'VICTORIAN SEWING BOX MEDIUM': 479,
#  'SET/10 RED POLKADOT PARTY CANDLES': 480,
#  'WASHROOM METAL SIGN': 481,
#  'BLACK SWEETHEART BRACELET': 482,
#  'DIAMANTE HAIR GRIP PACK/2 BLACK DIA': 483,
#  'BLACK DIAMANTE EXPANDABLE RING': 484,
#  'DIAMANTE HAIR GRIP PACK/2 RUBY': 485,
#  'DIAMANTE HAIR GRIP PACK/2 MONTANA': 486,
#  'BLUE SWEETHEART BRACELET': 487,
#  'PINK SWEETHEART BRACELET': 488,
#  'PURPLE SWEETHEART BRACELET': 489,
#  'RIBBON REEL CHRISTMAS PRESENT ': 490,
#  'FIRST AID TIN': 491,
#  'MAKE YOUR OWN MONSOON CARD KIT': 492,
#  'PACK OF 12 HEARTS DESIGN TISSUES ': 493,
#  'HEART FILIGREE DOVE LARGE': 494,
#  'SWIRLY CIRCULAR RUBBERS IN BAG': 495,
#  'VINTAGE PAISLEY STATIONERY SET': 496,
#  'SET/10 BLUE POLKADOT PARTY CANDLES': 497,
#  'RIBBON REEL SOCKS AND MITTENS': 498,
#  'CHRISTMAS METAL TAGS ASSORTED ': 499,
#  'CHRISTMAS TREE T-LIGHT HOLDER': 500,
#  'STAR  T-LIGHT HOLDER ': 501,
#  'HEART T-LIGHT HOLDER ': 502,
#  'MINI FUNKY DESIGN TAPES': 503,
#  'STAR WOODEN CHRISTMAS DECORATION': 504,
#  'WOODEN HEART CHRISTMAS SCANDINAVIAN': 505,
#  'CHRISTMAS RETROSPOT TREE WOOD': 506,
#  'SET/9 CHRISTMAS T-LIGHTS SCENTED ': 507,
#  'BLUE ROSE FABRIC MIRROR': 508,
#  'THREE CANVAS LUGGAGE TAGS': 509,
#  'RETROSPOT PARTY BAG + STICKER SET': 510,
#  'RETROSPOT SMALL TUBE MATCHES': 511,
#  '3D CHRISTMAS STAMPS STICKERS ': 512,
#  '36 FOIL HEART CAKE CASES': 513,
#  'PACK OF 6 SWEETIE GIFT BOXES': 514,
#  'CINAMMON SET OF 9 T-LIGHTS': 515,
#  'ORANGE SCENTED SET/9 T-LIGHTS': 516,
#  'RIBBON REEL STRIPES DESIGN ': 517,
#  'SET OF 2 TINS JARDIN DE PROVENCE': 518,
#  'MAKE YOUR OWN PLAYTIME CARD KIT': 519,
#  'DINOSAURS  WRITING SET ': 520,
#  'SKULLS WRITING SET ': 521,
#  'DOORMAT BLACK FLOCK ': 522,
#  'CHRISTMAS DECOUPAGE CANDLE': 523,
#  'OFFICE MUG WARMER POLKADOT': 524,
#  'BLACK RECORD COVER FRAME': 525,
#  'RECORD FRAME 7" SINGLE SIZE ': 526,
#  '36 PENCILS TUBE RED RETROSPOT': 527,
#  '36 PENCILS TUBE WOODLAND': 528,
#  'ROCKING HORSE RED CHRISTMAS ': 529,
#  'REGENCY CAKESTAND 3 TIER': 530,
#  'VINTAGE UNION JACK BUNTING': 531,
#  'RETRO LONGBOARD IRONING BOARD COVER': 532,
#  '3D DOG PICTURE PLAYING CARDS': 533,
#  'SAVE THE PLANET COTTON TOTE BAG': 534,
#  'PAPER BUNTING WHITE LACE': 535,
#  'GENTLEMAN SHIRT REPAIR KIT ': 536,
#  'CARD I LOVE LONDON ': 537,
#  'MIRRORED WALL ART FOXY': 538,
#  'MIRRORED WALL ART GENTS': 539,
#  'AIRLINE BAG VINTAGE JET SET WHITE': 540,
#  "POTTING SHED SOW 'N' GROW SET": 541,
#  'AIRLINE BAG VINTAGE WORLD CHAMPION ': 542,
#  'PINK HEARTS PAPER GARLAND': 543,
#  'POTTING SHED SEED ENVELOPES': 544,
#  'HI TEC ALPINE HAND WARMER': 545,
#  'POLYESTER FILLER PAD 45x45cm': 546,
#  'CARD DOLLY GIRL ': 547,
#  'CARD BILLBOARD FONT': 548,
#  'RAINY LADIES BIRTHDAY CARD': 549,
#  'RED WHITE SCARF  HOT WATER BOTTLE': 550,
#  'SET OF 2 TEA TOWELS APPLE AND PEARS': 551,
#  'LANTERN CREAM GAZEBO ': 552,
#  'BLUE BIRDHOUSE DECORATION': 553,
#  'ANTIQUE SILVER TEA GLASS ENGRAVED': 554,
#  'SET OF 2 WOODEN MARKET CRATES': 555,
#  'CLASSIC FRENCH STYLE BASKET NATURAL': 556,
#  'CRAZY DAISY HEART DECORATION': 557,
#  'CARD HOLDER GINGHAM HEART': 558,
#  'SMALL STRIPES CHOCOLATE GIFT BAG ': 559,
#  'TRAY, BREAKFAST IN BED': 560,
#  'PIZZA PLATE IN BOX': 561,
#  'PINK HEART DOTS HOT WATER BOTTLE': 562,
#  'PLACE SETTING WHITE HEART': 563,
#  'SET OF 4 NAPKIN CHARMS LEAVES   ': 564,
#  'SET OF 4 NAPKIN CHARMS STARS   ': 565,
#  'SET OF 4 NAPKIN CHARMS CUTLERY': 566,
#  'CARAVAN SQUARE TISSUE BOX': 567,
#  'BUTTON BOX ': 568,
#  '12 MESSAGE CARDS WITH ENVELOPES': 569,
#  'SMALL RED BABUSHKA NOTEBOOK ': 570,
#  'HERB MARKER MINT': 571,
#  'HERB MARKER ROSEMARY': 572,
#  'HERB MARKER BASIL': 573,
#  'HERB MARKER CHIVES ': 574,
#  'HERB MARKER PARSLEY': 575,
#  'HERB MARKER THYME': 576,
#  'METAL MERRY CHRISTMAS WREATH': 577,
#  'WHITE CHRISTMAS GARLAND STARS TREES': 578,
#  'RETROSPOT GIANT TUBE MATCHES': 579,
#  '36 FOIL STAR CAKE CASES ': 580,
#  'PACK OF 6 HANDBAG GIFT BOXES': 581,
#  'GARLAND WOODEN HAPPY EASTER': 582,
#  'CALENDAR PAPER CUT DESIGN': 583,
#  'CALENDAR IN SEASON DESIGN': 584,
#  'BLUE PAISLEY TISSUE BOX': 585,
#  'PINK PAISLEY SQUARE TISSUE BOX ': 586,
#  'TOAST ITS - HAPPY BIRTHDAY': 587,
#  'SET/10 IVORY POLKADOT PARTY CANDLES': 588,
#  'SKULLS STORAGE BOX SMALL': 589,
#  'JUMBO STORAGE BAG SKULLS': 590,
#  'GARDEN PATH JOURNAL': 591,
#  'BLACK ORANGE SQUEEZER': 592,
#  'SET OF 72 GREEN PAPER DOILIES': 593,
#  'RETROSPOT RED WASHING UP GLOVES': 594,
#  'SMALL LICORICE DES PINK BOWL': 595,
#  'SWISS ROLL TOWEL, CHOCOLATE  SPOTS': 596,
#  'PICNIC BASKET WICKER LARGE': 597,
#  'CREAM SWEETHEART EGG HOLDER': 598,
#  'PINK 3 PIECE POLKADOT CUTLERY SET': 599,
#  'PINK PARTY BAGS': 600,
#  'BLUE PARTY BAGS ': 601,
#  'PINK CREAM FELT CRAFT TRINKET BOX ': 602,
#  'RED RETROSPOT OVEN GLOVE DOUBLE': 603,
#  'RIDGED GLASS STORAGE JAR CREAM LID': 604,
#  'PACK OF 20 NAPKINS PANTRY DESIGN': 605,
#  'SWEETHEART CAKESTAND 3 TIER': 606,
#  'CHRISTMAS HANGING STAR WITH BELL': 607,
#  'MULTICOLOUR  CONFETTI IN TUBE': 608,
#  'CHOCOLATE 3 WICK MORRIS BOX CANDLE': 609,
#  'SET OF 16 VINTAGE PISTACHIO CUTLERY': 610,
#  'CHRISTMAS TOILET ROLL': 611,
#  'WHITE BELL HONEYCOMB PAPER ': 612,
#  ' 4 PURPLE FLOCK DINNER CANDLES': 613,
#  'PINK & WHITE BREAKFAST TRAY': 614,
#  'ENGLISH ROSE SPIRIT LEVEL ': 615,
#  'LARGE ROUND WICKER PLATTER ': 616,
#  'BLACK TEA TOWEL CLASSIC DESIGN': 617,
#  'CHRISTMAS LIGHTS 10 VINTAGE BAUBLES': 618,
#  'ROSES REGENCY TEACUP AND SAUCER ': 619,
#  'T-LIGHT HOLDER HANGING LACE': 620,
#  'HANGING HEART MIRROR DECORATION ': 621,
#  'CREAM SLICE FLANNEL CHOCOLATE SPOT ': 622,
#  'CREAM SLICE FLANNEL PINK SPOT ': 623,
#  'GREEN REGENCY TEACUP AND SAUCER': 624,
#  'EIGHT PIECE DINOSAUR SET': 625,
#  'HEADS AND TAILS SPORTING FUN': 626,
#  "ASS COL SMALL SAND GECKO P'WEIGHT": 627,
#  'ENAMEL MEASURING JUG CREAM': 628,
#  '12 PENCILS SMALL TUBE SKULL': 629,
#  '12 PENCIL SMALL TUBE WOODLAND': 630,
#  'BLUE PAPER PARASOL ': 631,
#  'VICTORIAN  METAL POSTCARD SPRING': 632,
#  'METAL 4 HOOK HANGER FRENCH CHATEAU': 633,
#  'BLACK KITCHEN SCALES': 634,
#  'RED KITCHEN SCALES': 635,
#  'IVORY KITCHEN SCALES': 636,
#  'MULTI COLOUR SILVER T-LIGHT HOLDER': 637,
#  '3 HOOK HANGER MAGIC GARDEN': 638,
#  'ASSORTED COLOUR LIZARD SUCTION HOOK': 639,
#  'JUMBO BAG WOODLAND ANIMALS': 640,
#  "CHILDREN'S CIRCUS PARADE MUG": 641,
#  'PACK 3 FIRE ENGINE/CAR PATCHES': 642,
#  'CARD PSYCHEDELIC APPLES': 643,
#  'IVORY ENCHANTED FOREST PLACEMAT': 644,
#  'PACK OF 6 PANNETONE GIFT BOXES': 645,
#  'MEASURING TAPE BABUSHKA RED': 646,
#  'RED ENCHANTED FOREST PLACEMAT': 647,
#  'CHILDRENS DOLLY GIRL MUG': 648,
#  'TOADSTOOL MONEY BOX': 649,
#  'MAKE YOUR OWN FLOWERPOWER CARD KIT': 650,
#  'PAPER CHAIN KIT LONDON': 651,
#  'MEASURING TAPE BABUSHKA BLUE': 652,
#  'PENCIL CASE LIFE IS BEAUTIFUL': 653,
#  'WOODEN ROUNDERS GARDEN SET ': 654,
#  'CHILDS BREAKFAST SET DOLLY GIRL ': 655,
#  'CHILDS BREAKFAST SET SPACEBOY ': 656,
#  'CAKE PLATE LOVEBIRD WHITE': 657,
#  'WOODEN ADVENT CALENDAR RED': 658,
#  'GREEN CHRISTMAS TREE CARD HOLDER': 659,
#  'STRING OF STARS CARD HOLDER': 660,
#  'SET/12 TAPER CANDLES': 661,
#  'MINT KITCHEN SCALES': 662,
#  'WHITE WOOD GARDEN PLANT LADDER': 663,
#  'GLASS JAR ENGLISH CONFECTIONERY': 664,
#  'GLASS JAR DIGESTIVE BISCUITS': 665,
#  'MILK BOTTLE WITH GLASS STOPPER ': 666,
#  'WELCOME  WOODEN BLOCK LETTERS': 667,
#  'SET/4 MODERN VINTAGE COTTON NAPKINS': 668,
#  'VINTAGE UNION JACK APRON': 669,
#  'SWALLOW SQUARE TISSUE BOX': 670,
#  'NO JUNK MAIL METAL SIGN': 671,
#  'SLATE TILE NATURAL HANGING': 672,
#  'VINTAGE GLASS COFFEE CADDY': 673,
#  'SILVER GLASS T-LIGHT SET': 674,
#  'RIDGED GLASS FINGER BOWL': 675,
#  'GLASS  BEURRE DISH': 676,
#  'GIN & TONIC DIET GREETING CARD ': 677,
#  'BIRTHDAY CARD, RETRO SPOT': 678,
#  'WRAP RED APPLES ': 679,
#  'RED RETROSPOT WRAP ': 680,
#  'WRAP CHRISTMAS SCREEN PRINT': 681,
#  'FANCY FONTS BIRTHDAY WRAP': 682,
#  'CLASSIC WHITE FRAME': 683,
#  'BLACK DINER WALL CLOCK': 684,
#  'DOORMAT PEACE ON EARTH BLUE': 685,
#  'BOX OF 24 COCKTAIL PARASOLS': 686,
#  'GROW YOUR OWN PLANT IN A CAN ': 687,
#  'PLASTERS IN TIN CIRCUS PARADE ': 688,
#  'PLASTERS IN TIN STRONGMAN': 689,
#  'MINI JIGSAW DINOSAUR ': 690,
#  'MINI JIGSAW BAKE A CAKE ': 691,
#  'MINI JIGSAW DOLLY GIRL': 692,
#  'WOODEN SCHOOL COLOURING SET': 693,
#  'PACK OF 12 TRADITIONAL CRAYONS': 694,
#  'CARD PARTY GAMES ': 695,
#  'BOOZE & WOMEN GREETING CARD ': 696,
#  'PACK OF 12 SUKI TISSUES ': 697,
#  'PACK OF 12 WOODLAND TISSUES ': 698,
#  'PACK OF 12 SKULL TISSUES': 699,
#  'PACK OF 12 BLUE PAISLEY TISSUES ': 700,
#  'PACK OF 12 CIRCUS PARADE TISSUES ': 701,
#  'PACK OF 12 SPACEBOY TISSUES': 702,
#  'LADS ONLY TISSUE BOX': 703,
#  'RED RETROSPOT TISSUE BOX': 704,
#  'PACK OF 12 PINK PAISLEY TISSUES ': 705,
#  'GINGERBREAD MAN COOKIE CUTTER': 706,
#  'GIN AND TONIC MUG': 707,
#  "IF YOU CAN'T STAND THE HEAT MUG": 708,
#  'I CAN ONLY PLEASE ONE PERSON MUG': 709,
#  'PINK HEART SHAPE EGG FRYING PAN': 710,
#  '200 RED + WHITE BENDY STRAWS': 711,
#  'RECIPE BOX RETROSPOT ': 712,
#  'RECIPE BOX PANTRY YELLOW DESIGN': 713,
#  'RECIPE BOX BLUE SKETCHBOOK DESIGN': 714,
#  '20 DOLLY PEGS RETROSPOT': 715,
#  'NO SINGING METAL SIGN': 716,
#  'BISCUIT TIN VINTAGE RED': 717,
#  'EMERGENCY FIRST AID TIN ': 718,
#  'POLKADOT PEN': 719,
#  'DECORATIVE PLANT POT WITH FRIEZE': 720,
#  'FRENCH BLUE METAL DOOR SIGN 5': 721,
#  'CHEST OF DRAWERS GINGHAM HEART ': 722,
#  'RED RETROSPOT CAKE STAND': 723,
#  'JOY WOODEN BLOCK LETTERS': 724,
#  'NOEL WOODEN BLOCK LETTERS ': 725,
#  'PEACE WOODEN BLOCK LETTERS': 726,
#  'OFFICE MUG WARMER BLACK+SILVER ': 727,
#  'SET OF 2 CHRISTMAS DECOUPAGE CANDLE': 728,
#  'COSMETIC BAG VINTAGE ROSE PAISLEY': 729,
#  'PINK ROSE FABRIC MIRROR': 730,
#  'SILVER PLATE CANDLE BOWL SMALL': 731,
#  'SMALL REGAL  SILVER CANDLEPOT ': 732,
#  'ANTIQUE TALL SWIRLGLASS TRINKET POT': 733,
#  'ANTIQUE GLASS PEDESTAL BOWL': 734,
#  'GUMBALL MAGAZINE RACK': 735,
#  'RED FLOWER CROCHET FOOD COVER': 736,
#  'CHERRY CROCHET FOOD COVER': 737,
#  'STRAWBERRY RAFFIA FOOD COVER': 738,
#  'POLKA DOT RAFFIA FOOD COVER': 739,
#  'DOORMAT SPOTTY HOME SWEET HOME': 740,
#  'T-LIGHT GLASS FLUTED ANTIQUE': 741,
#  'SILVER  CANDLEPOT JARDIN ': 742,
#  'POLKADOT MUG PINK ': 743,
#  'PAPER BUNTING COLOURED LACE': 744,
#  'ANTIQUE GLASS HEART DECORATION ': 745,
#  'SET OF 6 KASHMIR FOLKART BAUBLES': 746,
#  'CHRISTMAS RETROSPOT ANGEL WOOD': 747,
#  'CHRISTMAS RETROSPOT STAR WOOD': 748,
#  'HEART WOODEN CHRISTMAS DECORATION': 749,
#  'LARGE HANGING IVORY & RED WOOD BIRD': 750,
#  'SMALL HANGING IVORY/RED WOOD BIRD': 751,
#  'GRAND CHOCOLATECANDLE': 752,
#  'FAIRY CAKE BIRTHDAY CANDLE SET': 753,
#  '3 HOOK PHOTO SHELF ANTIQUE WHITE': 754,
#  'CREAM SWEETHEART WALL CABINET': 755,
#  'DOORMAT ENGLISH ROSE ': 756,
#  'DOORMAT UNION FLAG': 757,
#  'ROMANTIC IMAGES NOTEBOOK SET': 758,
#  'CURIOUS  IMAGES NOTEBOOK SET': 759,
#  'VINTAGE KEEPSAKE BOX PARIS DAYS': 760,
#  'RED GINGHAM ROSE JEWELLERY BOX': 761,
#  'BLUE CHARLIE+LOLA PERSONAL DOORSIGN': 762,
#  'CHARLIE+LOLA"EXTREMELY BUSY" SIGN': 763,
#  'CHARLOTTE BAG SUKI DESIGN': 764,
#  'LOLITA  DESIGN  COTTON TOTE BAG': 765,
#  'LETS GO SHOPPING COTTON TOTE BAG': 766,
#  'PAINT YOUR OWN CANVAS SET': 767,
#  'CAMOUFLAGE LED TORCH': 768,
#  'BLUE DRAGONFLY HELICOPTER': 769,
#  'YELLOW SHARK HELICOPTER': 770,
#  'RED SHARK HELICOPTER': 771,
#  'TOOL BOX SOFT TOY ': 772,
#  "DOCTOR'S BAG SOFT TOY": 773,
#  'CARRIAGE': 774,
#  'JUMBO BAG SCANDINAVIAN PAISLEY': 775,
#  'JUMBO BAG TOYS ': 776,
#  'PAINTED LIGHTBULB STAR+ MOON': 777,
#  'BLUE TEA TOWEL CLASSIC DESIGN': 778,
#  'SET 12 KIDS  WHITE CHALK STICKS': 779,
#  'CHRISTMAS MUSICAL ZINC STAR': 780,
#  'CHRISTMAS MUSICAL ZINC HEART ': 781,
#  'DOVE DECORATION PAINTED ZINC ': 782,
#  'UNION STRIPE WITH FRINGE  HAMMOCK': 783,
#  'FOLKART ZINC HEART CHRISTMAS DEC': 784,
#  'SKULLS AND CROSSBONES WRAP': 785,
#  'POLYESTER FILLER PAD 45x30cm': 786,
#  'POLYESTER FILLER PAD 40x40cm': 787,
#  'PINK FLOWER FABRIC PONY': 788,
#  'BIRTHDAY PARTY CORDON BARRIER TAPE': 789,
#  'CAMOUFLAGE DESIGN TEDDY': 790,
#  'TV DINNER TRAY AIR HOSTESS ': 791,
#  'SUKI  SHOULDER BAG': 792,
#  'BLUE SPOT CERAMIC DRAWER KNOB': 793,
#  'CUSHION COVER PINK UNION JACK': 794,
#  'CREAM SWEETHEART LETTER RACK': 795,
#  'FOUR HOOK  WHITE LOVEBIRDS': 796,
#  'FRENCH BLUE METAL DOOR SIGN 3': 797,
#  'FRENCH BLUE METAL DOOR SIGN No': 798,
#  'SET OF 3 BABUSHKA STACKING TINS': 799,
#  'BEACH HUT KEY CABINET': 800,
#  'SMALL PURPLE BABUSHKA NOTEBOOK ': 801,
#  'CHERRY BLOSSOM PASSPORT COVER': 802,
#  'SMALL YELLOW BABUSHKA NOTEBOOK ': 803,
#  'RETRO MOD TRAY': 804,
#  'SWEETHEART WIRE MAGAZINE RACK': 805,
#  'CARDHOLDER HOLLY WREATH METAL': 806,
#  'SILVER CHRISTMAS TREE BAUBLE STAND ': 807,
#  'SWEETHEART RECIPE BOOK STAND': 808,
#  'OVERNIGHT BAG VINTAGE ROSE PAISLEY': 809,
#  'ANT WHITE WIRE HEART SPIRAL': 810,
#  'FEATHER PEN,COAL BLACK': 811,
#  'FEATHER PEN,LIGHT PINK': 812,
#  'FEATHER PEN,HOT PINK': 813,
#  'DOORMAT AIRMAIL ': 814,
#  'NUMBER TILE COTTAGE GARDEN 8': 815,
#  'DOORMAT 3 SMILEY CATS': 816,
#  'BREAD BIN DINER STYLE IVORY': 817,
#  'BREAD BIN DINER STYLE RED ': 818,
#  'MAGNETS PACK OF 4 VINTAGE COLLAGE': 819,
#  'MAGNETS PACK OF 4 HOME SWEET HOME': 820,
#  'MAGNETS PACK OF 4 CHILDHOOD MEMORY': 821,
#  'ART LIGHTS,FUNK MONKEY': 822,
#  'MINI CAKE STAND WITH HANGING CAKES': 823,
#  'CERAMIC CAKE STAND + HANGING CAKES': 824,
#  'SWEETHEART CERAMIC TRINKET BOX': 825,
#  'SET OF 4 FAIRY CAKE PLACEMATS': 826,
#  'OFFICE MUG WARMER PINK': 827,
#  'OFFICE MUG WARMER CHOC+BLUE': 828,
#  'PLEASE ONE PERSON METAL SIGN': 829,
#  'GLITTER CHRISTMAS HEART ': 830,
#  'CIRCUS PARADE CHILDRENS EGG CUP ': 831,
#  'RED STRIPE CERAMIC DRAWER KNOB': 832,
#  'NURSERY A,B,C PAINTED LETTERS': 833,
#  'SET OF 2 ROUND TINS DUTCH CHEESE': 834,
#  'GREEN GEISHA GIRL ': 835,
#  'BLUE GEISHA GIRL ': 836,
#  'NEWSPAPER STAND': 837,
#  'CINAMMON & ORANGE WREATH': 838,
#  'LARGE WHITE HONEYCOMB PAPER BELL  ': 839,
#  'WOOD STOCKING CHRISTMAS SCANDISPOT': 840,
#  'SET OF 4 NAPKIN CHARMS HEARTS': 841,
#  'WOODEN TREE CHRISTMAS SCANDINAVIAN': 842,
#  'ROCKING HORSE GREEN CHRISTMAS ': 843,
#  'CHRISTMAS HANGING TREE WITH BELL': 844,
#  'JINGLE BELLS TREE DECORATION': 845,
#  'SET OF 4 NAPKIN CHARMS 3 KEYS ': 846,
#  'SET OF 4 NAPKIN CHARMS INSTRUMENT': 847,
#  'SET OF 4 NAPKIN CHARMS CROWNS ': 848,
#  'SWALLOW WOODEN CHRISTMAS DECORATION': 849,
#  'GLITTER CHRISTMAS TREE': 850,
#  'GARLAND WITH STARS AND BELLS': 851,
#  'CHRISTMAS GARLAND STARS,TREES': 852,
#  'SWISS CHALET TREE DECORATION ': 853,
#  'BIRD BOX CHRISTMAS TREE DECORATION': 854,
#  'WOODEN ADVENT CALENDAR CREAM': 855,
#  'Manual': 856,
#  'CARD MOTORBIKE SANTA': 857,
#  'CARD CHRISTMAS VILLAGE': 858,
#  'DOORMAT I LOVE LONDON': 859,
#  'WOOD AND GLASS MEDICINE CABINET': 860,
#  'MA CAMPAGNE CUTLERY BOX': 861,
#  'YULETIDE IMAGES GIFT WRAP SET': 862,
#  'WICKER WREATH LARGE': 863,
#  'TABLE LAMP WHITE SHADE WOOD BASE': 864,
#  'SMALL FOLKART STAR CHRISTMAS DEC': 865,
#  'SMALLFOLKART BAUBLE CHRISTMAS DEC': 866,
#  'SMALL HANGING GLASS+ZINC LANTERN': 867,
#  'SET/3 CHRISTMAS DECOUPAGE CANDLES': 868,
#  'PINK/WHITE CHRISTMAS TREE 60CM': 869,
#  'GREEN CHRISTMAS TREE STRING 20LIGHT': 870,
#  'EUCALYPTUS & PINECONE  WREATH': 871,
#  'CHRISTMAS PUDDING TRINKET POT ': 872,
#  'BLACK CHRISTMAS TREE 60CM': 873,
#  '15CM CHRISTMAS GLASS BALL 20 LIGHTS': 874,
#  'CARDHOLDER GINGHAM STAR': 875,
#  'WOODEN STAR CHRISTMAS SCANDINAVIAN': 876,
#  'FINE WICKER HEART ': 877,
#  'UNION JACK FLAG PASSPORT COVER ': 878,
#  'EDWARDIAN PARASOL PINK': 879,
#  'S/4 CACTI CANDLES': 880,
#  'PINK MARSHMALLOW SCARF KNITTING KIT': 881,
#  '6 CHOCOLATE LOVE HEART T-LIGHTS': 882,
#  'PINK BLUE FELT CRAFT TRINKET BOX': 883,
#  'TOAST ITS - BEST MUM': 884,
#  '3 TRADITIONAL COOKIE CUTTERS  SET': 885,
#  'CHILDRENS SPACEBOY MUG': 886,
#  'MIRRORED WALL ART SKULLS': 887,
#  'MIRRORED WALL ART STARS': 888,
#  'CHARLIE+LOLA PINK HOT WATER BOTTLE': 889,
#  'CHARLIE+LOLA RED HOT WATER BOTTLE ': 890,
#  'COWBOYS AND INDIANS BIRTHDAY CARD ': 891,
#  'RING OF ROSES BIRTHDAY CARD': 892,
#  'ALARM CLOCK BAKELIKE CHOCOLATE': 893,
#  'CERAMIC CAKE DESIGN SPOTTED MUG': 894,
#  'LIPSTICK PEN FUSCHIA': 895,
#  'BROCADE RING PURSE ': 896,
#  'GREEN 3 PIECE POLKADOT CUTLERY SET': 897,
#  'PAINTED METAL PEARS ASSORTED': 898,
#  'COLOUR GLASS. STAR T-LIGHT HOLDER': 899,
#  'SWALLOWS GREETING CARD': 900,
#  'LADLE LOVE HEART PINK': 901,
#  'LETTER "M" BLING KEY RING': 902,
#  'LETTER "V" BLING KEY RING': 903,
#  'LETTER "S" BLING KEY RING': 904,
#  'LETTER "J" BLING KEY RING': 905,
#  'WALL TIDY RETROSPOT ': 906,
#  'BINGO SET': 907,
#  'KIDS RAIN MAC PINK': 908,
#  'RED RETROSPOT CUP': 909,
#  'SQUARE FLOOR CUSHION VINTAGE RED': 910,
#  'SET/3 VANILLA SCENTED CANDLE IN BOX': 911,
#  'SET OF 2 TINS VINTAGE BATHROOM ': 912,
#  'BLUE  DIAMANTE PEN IN GIFT BOX': 913,
#  '36 PENCILS TUBE SKULLS': 914,
#  'GREEN FERN JOURNAL ': 915,
#  'RIBBON REEL FLORA + FAUNA ': 916,
#  'BLACK EAR MUFF HEADPHONES': 917,
#  'RED POLKADOT COFFEE  MUG': 918,
#  'EMPIRE UNION JACK TV DINNER TRAY': 919,
#  'ASSORTED TUTTI FRUTTI MIRROR': 920,
#  'SET OF 4 ROSE BOTANICAL CANDLES': 921,
#  'FELT EGG COSY BLUE RABBIT ': 922,
#  'LOVE HEART SOCK HANGER': 923,
#  'SCOTTIES CHILDRENS APRON': 924,
#  'CHILDS GARDEN BRUSH PINK': 925,
#  'LADYBIRD + BEE RAFFIA FOOD COVER': 926,
#  'HOME SWEET HOME MUG': 927,
#  'CHILDRENS GARDEN GLOVES BLUE': 928,
#  'CHRYSANTHEMUM SKETCHBOOK ': 929,
#  'BAG 250g SWIRLY MARBLES': 930,
#  'BAG 125g SWIRLY MARBLES': 931,
#  'ROSE 3 WICK MORRIS BOX CANDLE': 932,
#  'ROSE SCENT CANDLE JEWELLED DRAWER': 933,
#  'RED RETROSPOT CHILDRENS UMBRELLA': 934,
#  'WHITE BAMBOO RIBS LAMPSHADE': 935,
#  'FOLDING UMBRELLA CHOCOLATE POLKADOT': 936,
#  'CAKE STAND LOVEBIRD 2 TIER WHITE': 937,
#  '3 GARDENIA MORRIS BOXED CANDLES': 938,
#  'SET/4 GARDEN ROSE DINNER CANDLE': 939,
#  'GOLD PRINT PAPER BAG': 940,
#  'WOODEN HAPPY BIRTHDAY GARLAND': 941,
#  'SET/4 BADGES CUTE CREATURES': 942,
#  'BLUE PAISLEY POCKET BOOK': 943,
#  'PORCELAIN ROSE LARGE ': 944,
#  'PORCELAIN ROSE SMALL': 945,
#  'BAKING SET SPACEBOY DESIGN': 946,
#  'SOAP DISH BROCANTE': 947,
#  'FLUTED ANTIQUE CANDLE HOLDER': 948,
#  'PEACE SMALL WOOD LETTERS': 949,
#  'RED RETROSPOT APRON ': 950,
#  'TEA TIME KITCHEN APRON': 951,
#  'FELTCRAFT DOLL MARIA': 952,
#  'PARTY METAL SIGN ': 953,
#  'VINTAGE CREAM 3 BASKET CAKE STAND': 954,
#  'CHRISTMAS RETROSPOT HEART WOOD': 955,
#  'DOORMAT RESPECTABLE HOUSE': 956,
#  'MEMO BOARD RETROSPOT  DESIGN': 957,
#  'PINK/YELLOW FLOWERS HANDBAG': 958,
#  'CHARLIE+LOLA MY ROOM DOOR SIGN': 959,
#  'SALLE DE BAIN HOOK': 960,
#  'CHRISTMAS CARD STACK OF PRESENTS': 961,
#  'SET 12 KIDS COLOUR  CHALK STICKS': 962,
#  'SPACEBOY BIRTHDAY CARD': 963,
#  'ROBOT BIRTHDAY CARD': 964,
#  'JOY LARGE WOOD LETTERS': 965,
#  'WORLD WAR 2 GLIDERS ASSTD DESIGNS': 966,
#  'CHILDRENS APRON APPLES DESIGN': 967,
#  'ENCHANTED BIRD COATHANGER 5 HOOK': 968,
#  'TOAST ITS - FAIRY FLOWER': 969,
#  'CACTI T-LIGHT CANDLES': 970,
#  'HANGING BAUBLE T-LIGHT HOLDER SMALL': 971,
#  '12 PENCILS SMALL TUBE RED RETROSPOT': 972,
#  'BALLOON WATER BOMB PACK OF 35': 973,
#  'BALLOON PUMP WITH 10 BALLOONS': 974,
#  'ALPHABET STENCIL CRAFT': 975,
#  '3 TRADITIONAl BISCUIT CUTTERS  SET': 976,
#  'IVORY PAPER CUP CAKE CASES ': 977,
#  'PARTY INVITES WOODLAND': 978,
#  'PARTY INVITES BALLOON GIRL': 979,
#  'LOVELY BONBON STICKER SHEET': 980,
#  'SWEET PUDDING STICKER SHEET': 981,
#  'ASSTD DESIGN 3D PAPER STICKERS': 982,
#  'CUTE CATS TAPE': 983,
#  'TOOTHPASTE TUBE PEN': 984,
#  'MAGIC DRAWING SLATE PURDEY': 985,
#  'PACK OF 12 COLOURED PENCILS': 986,
#  'TOAST ITS - I LOVE YOU ': 987,
#  'BANK ACCOUNT  GREETING  CARD ': 988,
#  'EMPIRE BIRTHDAY CARD': 989,
#  'TEA PARTY BIRTHDAY CARD': 990,
#  'CARD CAT AND TREE ': 991,
#  'CARD DOG AND BALL ': 992,
#  'PENNY FARTHING BIRTHDAY CARD': 993,
#  'BLUE STRIPE CERAMIC DRAWER KNOB': 994,
#  'RED SPOT CERAMIC DRAWER KNOB': 995,
#  'WHITE SPOT BLUE CERAMIC DRAWER KNOB': 996,
#  'HOOK, 1 HANGER ,MAGIC GARDEN': 997,
#  'EMBOSSED GLASS TEALIGHT HOLDER': 998,
#  'WATERING CAN PINK BUNNY': 999,
#  'WATERING CAN GREEN DINOSAUR': 1000,
#  ...}

# %%
user_data["Product_id"] = user_data["Description"]
user_data["Product_id"] = user_data["Product_id"].map(desc_dict)
user_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
#
#   days_last_purchase  days_last_purchase_num  Product_id
# 0  374 days 04:24:00                   374.0           1
# 1  374 days 04:24:00                   374.0           2
# 2  374 days 04:24:00                   374.0           3
# 3  374 days 04:24:00                   374.0           4
# 4  374 days 04:24:00                   374.0           5
