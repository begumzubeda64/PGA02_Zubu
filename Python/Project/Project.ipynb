# %%
#Youtube Video Statistics - Begum Zubeda
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Import dataset
youtube_df = pd.read_csv(r"C:\zubeda\PGA-02\Python\Project\Dataset\train.csv")

youtube_df.head()
# Out:
#      Video_id category_id          channel_title  subscriber  \
# 0   HDR9SQc79          22           CaseyNeistat   9086142.0
# 1  KNH52UF?48          24        LastWeekTonight   5937292.0
# 2  QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3  MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4  TWP93KXT70          24               nigahiga  20563106.0
#
#                                                title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  The Trump Presidency: Last Week Tonight with J...
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                   Nickelback Lyrics: Real or Fake?
# 4                           I Dare You: GOING BALD!?
#
#                                                 tags  \
# 0                                    SHANtell martin
# 1  last week tonight trump presidency|last week t...
# 2  racist superman|rudy|mancuso|king|bach|racist|...
# 3  rhett and link|gmm|good mythical morning|rhett...
# 4  ryan|higa|higatv|nigahiga|i dare you|idy|rhpc|...
#
#                                          description  Trend_day_count  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...              6.0
# 1  One year after the presidential election, John...              1.0
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...             10.0
# 3  Today we find out if Link is a Nickelback amat...             12.0
# 4  I know it's been a while since we did this sho...             11.0
#
#   Tag_count Trend_tag_count comment_count comment_disabled  \
# 0        21               6                          FALSE
# 1        23               1        116266             TRUE
# 2        22               3        257850             TRUE
# 3        17               5        263939             TRUE
# 4        15               7        268085             TRUE
#
#   like dislike disabled  likes dislike tag appered in title    views  \
# 0                 FALSE  13342    6089                False  1978978
# 1                 FALSE   5761    3044                False  1487870
# 2                  TRUE      0       0                 True  1502102
# 3                  TRUE      0       0                 True  3519302
# 4                  TRUE      0       0                 True  4835374
#
#    Unnamed: 17 Unnamed: 18
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN

# %%
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               3198 non-null   object
#  1   category_id            3192 non-null   object
#  2   channel_title          3195 non-null   object
#  3   subscriber             3175 non-null   float64
#  4   title                  3195 non-null   object
#  5   tags                   3046 non-null   object
#  6   description            3133 non-null   object
#  7   Trend_day_count        3197 non-null   float64
#  8   Tag_count              3197 non-null   object
#  9   Trend_tag_count        3197 non-null   object
#  10  comment_count          3198 non-null   object
#  11  comment_disabled       3198 non-null   object
#  12  like dislike disabled  3198 non-null   object
#  13  likes                  3198 non-null   object
#  14  dislike                3198 non-null   object
#  15  tag appered in title   3197 non-null   object
#  16  views                  3198 non-null   object
#  17  Unnamed: 17            1 non-null      float64
#  18  Unnamed: 18            1 non-null      object
# dtypes: float64(3), object(16)
# memory usage: 474.8+ KB

# %%
#Dataframe shape
youtube_df.shape
# Out:
# (3198, 19)

# %%
#Check Datatypes
youtube_df.dtypes
# Out:
# Video_id                  object
# category_id               object
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                 object
# Trend_tag_count           object
# comment_count             object
# comment_disabled          object
# like dislike disabled     object
# likes                     object
# dislike                   object
# tag appered in title      object
# views                     object
# Unnamed: 17              float64
# Unnamed: 18               object
# dtype: object

# %%
#Check null values in percentage
youtube_df.isnull().sum()*100 / youtube_df.shape[0]
# Out:
# Video_id                  0.000000
# category_id               0.187617
# channel_title             0.093809
# subscriber                0.719199
# title                     0.093809
# tags                      4.752971
# description               2.032520
# Trend_day_count           0.031270
# Tag_count                 0.031270
# Trend_tag_count           0.031270
# comment_count             0.000000
# comment_disabled          0.000000
# like dislike disabled     0.000000
# likes                     0.000000
# dislike                   0.000000
# tag appered in title      0.031270
# views                     0.000000
# Unnamed: 17              99.968730
# Unnamed: 18              99.968730
# dtype: float64

# %%
#Remove null columns
youtube_df.drop(youtube_df.columns[[-1, -2]], axis=1, inplace=True)
youtube_df.head()
# Out:
#      Video_id category_id          channel_title  subscriber  \
# 0   HDR9SQc79          22           CaseyNeistat   9086142.0
# 1  KNH52UF?48          24        LastWeekTonight   5937292.0
# 2  QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3  MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4  TWP93KXT70          24               nigahiga  20563106.0
#
#                                                title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  The Trump Presidency: Last Week Tonight with J...
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                   Nickelback Lyrics: Real or Fake?
# 4                           I Dare You: GOING BALD!?
#
#                                                 tags  \
# 0                                    SHANtell martin
# 1  last week tonight trump presidency|last week t...
# 2  racist superman|rudy|mancuso|king|bach|racist|...
# 3  rhett and link|gmm|good mythical morning|rhett...
# 4  ryan|higa|higatv|nigahiga|i dare you|idy|rhpc|...
#
#                                          description  Trend_day_count  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...              6.0
# 1  One year after the presidential election, John...              1.0
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...             10.0
# 3  Today we find out if Link is a Nickelback amat...             12.0
# 4  I know it's been a while since we did this sho...             11.0
#
#   Tag_count Trend_tag_count comment_count comment_disabled  \
# 0        21               6                          FALSE
# 1        23               1        116266             TRUE
# 2        22               3        257850             TRUE
# 3        17               5        263939             TRUE
# 4        15               7        268085             TRUE
#
#   like dislike disabled  likes dislike tag appered in title    views
# 0                 FALSE  13342    6089                False  1978978
# 1                 FALSE   5761    3044                False  1487870
# 2                  TRUE      0       0                 True  1502102
# 3                  TRUE      0       0                 True  3519302
# 4                  TRUE      0       0                 True  4835374

# %%
#Fill null rows
youtube_df['category_id'].fillna(0, inplace=True)
youtube_df['channel_title'].fillna('Anonymous', inplace=True)
youtube_df['subscriber'].fillna(0, inplace=True)
youtube_df['title'].fillna('No title', inplace=True)
youtube_df['tags'].fillna('No tags', inplace=True)
youtube_df['description'].fillna('No description', inplace=True)
youtube_df['Trend_day_count'].fillna(0, inplace=True)
youtube_df['Tag_count'].fillna(0, inplace=True)
youtube_df['Trend_tag_count'].fillna(0, inplace=True)
youtube_df['tag appered in title'].fillna('No title tag', inplace=True)

youtube_df.isnull().sum()*100 / youtube_df.shape[0]
# Out:
# Video_id                 0.0
# category_id              0.0
# channel_title            0.0
# subscriber               0.0
# title                    0.0
# tags                     0.0
# description              0.0
# Trend_day_count          0.0
# Tag_count                0.0
# Trend_tag_count          0.0
# comment_count            0.0
# comment_disabled         0.0
# like dislike disabled    0.0
# likes                    0.0
# dislike                  0.0
# tag appered in title     0.0
# views                    0.0
# dtype: float64

# %%
#Replace inconsistent data
columns = ['Tag_count', 'Trend_tag_count', 'comment_count', 'likes', 'dislike', 'views']
regex = [r'^[A-Za-z)(<>+-/@_.&#\s]+', '', '#VALUE!', True, False]
youtube_df[columns] = youtube_df[columns].replace(regex=regex, value=0)
youtube_df['like dislike disabled'] = youtube_df['like dislike disabled'].replace(regex=r'^[0-9]+', value='FALSE')
youtube_df['comment_disabled'] = youtube_df['comment_disabled'].replace(regex=r'^[0-9]+', value='FALSE')

# %%
#Convert columns to valid datatypes
columns = ['Tag_count', 'Trend_tag_count', 'comment_count', 'likes', 'dislike', 'views']
youtube_df[columns] = youtube_df[columns].astype(float)

youtube_df.dtypes
# Out:
# Video_id                  object
# category_id               object
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                float64
# Trend_tag_count          float64
# comment_count            float64
# comment_disabled          object
# like dislike disabled     object
# likes                    float64
# dislike                  float64
# tag appered in title      object
# views                    float64
# dtype: object

# %%
youtube_df.tail(10)
# Out:
#         Video_id category_id            channel_title  subscriber  \
# 3188  AVI91YQD43          24                  Variety    230720.0
# 3189  UGJ10XAb33          26              AmazingPhil   4232293.0
# 3190   PTM7WHf59          17                      NBA   8707071.0
# 3191   ISJ87JHs2          22             Grace Helbig   3008137.0
# 3192  ZGR33QU@74          24  Trailers Promos Teasers         0.0
# 3193  OKR48DOE67          20           EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91          10            JackWhiteVEVO    261596.0
# 3195  VHF51NVr11          10           JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39          26               Refinery29    890739.0
# 3197  IFD79NSG47          22                  MN khan         0.0
#
#                                                   title  \
# 3188  Chloe Grace Moretz on Louis C.K. and the #MeTo...
# 3189               I Read A Letter From My Younger Self
# 3190  Team LeBron! Best Plays from Every All-Star on...
# 3191          My Bachelor Audition Tape // Grace Helbig
# 3192                        The Hurricane Heist Trailer
# 3193      FIFA 18 - FUT Champions Cup Barcelona - Day 1
# 3194                   Jack White - Corporation (Audio)
# 3195  James Blake - If The Car Beside You Moves Ahea...
# 3196  Lucie Fink Trains Like A Professional Gymnast ...
# 3197  Man drops magnum of Champagne on the floor in ...
#
#                                                    tags  \
# 3188                             Variety|Variety Studio
# 3189  amazingphil|phil lester|phil|letter|from|my|pa...
# 3190  nba|highlights|basketball|plays|amazing|sports...
# 3191  grace|grace helbig|graceinabox|youtube grace h...
# 3192    The Hurricane Heist Trailer|The Hurricane Heist
# 3193  fifa|fifa ultimate team|fut|fifa pack opening|...
# 3194  Alternative|Corporation|Jack White|Third Man R...
# 3195  James|Blake|If|The|Car|Beside|You|Moves|Ahead|...
# 3196  refinery29|refinery 29|r29|r29 video|refinery2...
# 3197                                            No tags
#
#                                             description  Trend_day_count  \
# 3188  http://bit.ly/VarietySubscribe\n\nhttp://www.f...              6.0
# 3189  I read an email I wrote to myself 10 years ago...              1.0
# 3190  Check out the best plays from All-Star captain...              4.0
# 3191  My official audition tape for the next season ...              6.0
# 3192  Under the threat of a hurricane, opportunistic...              9.0
# 3193  Day 1 of the FUT Champions Cup Barcelona featu...              7.0
# 3194  “Corporation” by Jack White from the forthcomi...              7.0
# 3195  If the car beside you moves ahead \nAs much as...             11.0
# 3196  On this episode of Lucie For Hire, our host Lu...             11.0
# 3197  Man spills magnum of champagne ‘worth £30,000’...             12.0
#
#       Tag_count  Trend_tag_count  comment_count comment_disabled  \
# 3188       12.0              6.0       100886.0             TRUE
# 3189       11.0              7.0        56438.0             TRUE
# 3190       24.0              1.0            0.0            FALSE
# 3191       21.0              6.0            0.0            FALSE
# 3192       11.0              3.0        86622.0             TRUE
# 3193       20.0              5.0            0.0            FALSE
# 3194        8.0              6.0            0.0            FALSE
# 3195       15.0              4.0            0.0            FALSE
# 3196       14.0              6.0       250750.0             TRUE
# 3197       12.0              4.0        32337.0             TRUE
#
#      like dislike disabled    likes  dislike tag appered in title      views
# 3188                 FALSE  14426.0  11069.0                 True   387483.0
# 3189                 FALSE  16257.0   8685.0                 True  1063118.0
# 3190                  TRUE      0.0      0.0                 True  1827626.0
# 3191                 FALSE  10254.0   8834.0                False   702498.0
# 3192                  TRUE      0.0      0.0                 True  1028362.0
# 3193                 FALSE   9734.0   5912.0                False   747960.0
# 3194                 FALSE  16006.0  12019.0                 True   200410.0
# 3195                  TRUE      0.0      0.0                 True   244022.0
# 3196                 FALSE   6859.0   1247.0                 True   907340.0
# 3197                 FALSE   8339.0   5436.0                 True   465531.0

# %%
youtube_df.describe()
# Out:
#          subscriber  Trend_day_count    Tag_count  Trend_tag_count  \
# count  3.198000e+03      3198.000000  3198.000000      3198.000000
# mean   3.796479e+06         7.961851    18.609131         7.113196
# std    2.855627e+07        78.543895    80.355531       175.056899
# min    0.000000e+00         0.000000     0.000000         0.000000
# 25%    2.326040e+05         4.000000    12.000000         2.000000
# 50%    1.206997e+06         7.000000    17.000000         4.000000
# 75%    3.808198e+06        10.000000    21.000000         6.000000
# max    1.576229e+09      4444.000000  3225.000000      9903.000000
#
#        comment_count         likes       dislike         views
# count    3198.000000  3.198000e+03   3198.000000  3.198000e+03
# mean   112487.494371  9.763094e+03   5782.877423  1.571630e+06
# std    101861.271626  2.240396e+04   4861.070612  2.053533e+07
# min         0.000000  0.000000e+00      0.000000  0.000000e+00
# 25%         0.000000  0.000000e+00      0.000000  4.304118e+05
# 50%     99582.000000  1.022150e+04   5351.500000  7.080920e+05
# 75%    203208.250000  1.505300e+04  10040.250000  1.204446e+06
# max    299877.000000  1.213628e+06  14858.000000  9.898735e+08

# %%
plt.style.use('seaborn-darkgrid')

#Number of videos where likes and dislikes are disbaled
plt.hist(x=youtube_df['like dislike disabled'], color='darkviolet')

plt.title("Distribution of Likes, Dislikes Disabled")
plt.xlabel('Likes, Dislikes Disabled')
plt.xticks([0.05, 0.95], ["No", "Yes"])
plt.ylabel('Frequency')

plt.show()

# %%
#Number of videos where comments are disbaled
plt.hist(x=youtube_df['comment_disabled'], color='m')

plt.title("Distribution of Comment Disabled")
plt.xlabel('Comment Disabled')
plt.xticks([0.05, 0.95], ["No", "Yes"])
plt.ylabel('Frequency')

plt.show()

# %%
#Frequency Disributions of data
fig = plt.figure(figsize=(8,8))

ax = fig.gca()
youtube_df.hist(ax=ax, color="cyan")
plt.show()
# Out:
# <ipython-input-9-f27cadb55093>:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   youtube_df.hist(ax=ax, color="cyan")

# %%
#Boxplot for likes, dislikes, comments count
plt.boxplot([youtube_df['likes'], youtube_df['dislike'], youtube_df['comment_count']])

plt.title("Distribution of Likes, Dislikes and Comments")
plt.xticks([1, 2, 3],["Likes", "Dislikes", "Comments"])
plt.show()

# %%
#Boxplot for Trend_day_count, Tag_count, Trend_tag_count
plt.boxplot([youtube_df['Trend_day_count'], youtube_df['Tag_count'], youtube_df['Trend_tag_count']])

plt.title("Distribution of Trend_day_count, Tag_count and Trend_tag_count")
plt.xticks([1, 2, 3],["Trend_day_count", "Tag_count", "Trend_tag_count"])
plt.show()

# %%
#Boxplot for Subscribers, Views
plt.boxplot([youtube_df['subscriber'], youtube_df['views']])

plt.title("Distribution of Subscribers, Views")
plt.xticks([1, 2],["Subscribers", "Views"])
plt.show()

# %%
#Relationship between Variables
youtube_df.corr()
# Out:
#                  subscriber  Trend_day_count  Tag_count  Trend_tag_count  \
# subscriber         1.000000        -0.001403  -0.002943        -0.000915
# Trend_day_count   -0.001403         1.000000  -0.000521         0.001204
# Tag_count         -0.002943        -0.000521   1.000000         0.001400
# Trend_tag_count   -0.000915         0.001204   0.001400         1.000000
# comment_count      0.007140         0.003003   0.003033        -0.019444
# likes             -0.008582         0.002038  -0.012868        -0.004323
# dislike           -0.019086         0.006965  -0.030584        -0.013678
# views              0.007321        -0.000401  -0.001519        -0.001007
#
#                  comment_count     likes   dislike     views
# subscriber            0.007140 -0.008582 -0.019086  0.007321
# Trend_day_count       0.003003  0.002038  0.006965 -0.000401
# Tag_count             0.003033 -0.012868 -0.030584 -0.001519
# Trend_tag_count      -0.019444 -0.004323 -0.013678 -0.001007
# comment_count         1.000000  0.002694  0.006452  0.039945
# likes                 0.002694  1.000000  0.297125 -0.007328
# dislike               0.006452  0.297125  1.000000 -0.024774
# views                 0.039945 -0.007328 -0.024774  1.000000

# %%
sns.pairplot(data=youtube_df)

plt.show()

# %%
sns.heatmap(data=youtube_df.corr(), annot=True, linewidth=0.5, cmap="BuGn", cbar=True, vmin=-1, vmax=1)

plt.show()
